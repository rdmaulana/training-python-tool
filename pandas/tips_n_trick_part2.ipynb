# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dataset/titanicfull.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# # rename kolom dan cleaning kolom, lowercase

# %%
df.columns = ['Pclass', 'Survival status', 'full Name', ' SeX', 'Age ', 'Sib SP', 'Parch',
             'Ticket', 'Fare', 'Cabin', 'Embarked']
df_backup = df.copy(deep=True)

df.head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       SeX   Age   Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %%
df.columns = df.columns.str.lower().str.strip('_').str.replace(' ', '_')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pclass           1309 non-null   int64
#  1   survival_status  1309 non-null   int64
#  2   full_name        1309 non-null   object
#  3   sex              1309 non-null   object
#  4   age              1046 non-null   float64
#  5   sib_sp           1309 non-null   int64
#  6   parch            1309 non-null   int64
#  7   ticket           1309 non-null   object
#  8   fare             1308 non-null   float64
#  9   cabin            295 non-null    object
#  10  embarked         1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# # Seleksi kolom dan baris

# %%
df.loc[[0,99,120], ['full_name','age']] #kiri -> baris , kanan -> kolom
# Out:
#                                              full_name   age
# 0                        Allen, Miss. Elisabeth Walton  29.0
# 99   Duff Gordon, Lady. (Lucille Christiana Sutherl...  48.0
# 120                       Frauenthal, Mr. Isaac Gerald  43.0

# %% [markdown]
# # Seleksi kolom dan baris dgn kondisi

# %%
# df['age'] = df['age'].astype(int)
df.loc[df['age'] > 40, ['full_name', 'age', 'sex', 'survival_status']]
# Out:
#                                           full_name   age     sex  \
# 5                               Anderson, Mr. Harry  48.0    male
# 6                 Andrews, Miss. Kornelia Theodosia  63.0  female
# 8     Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0  female
# 9                           Artagaveytia, Mr. Ramon  71.0    male
# 10                           Astor, Col. John Jacob  47.0    male
# ...                                             ...   ...     ...
# 1264                van Billiard, Mr. Austin Blyler  40.5    male
# 1272                    Vander Cruyssen, Mr. Victor  47.0    male
# 1287               Widegren, Mr. Carl/Charles Peter  51.0    male
# 1290               Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 1301                           Youseff, Mr. Gerious  45.5    male
#
#       survival_status
# 5                   1
# 6                   1
# 8                   1
# 9                   0
# 10                  0
# ...               ...
# ...

# %% [markdown]
# # Slicing data frame

# %%
df.loc[0:10, ['full_name', 'age', 'sex', 'survival_status']] # nampilin data index 0 sampe 10
# Out:
#                                           full_name    age     sex  \
# 0                     Allen, Miss. Elisabeth Walton  29.00  female
# 1                    Allison, Master. Hudson Trevor   0.92    male
# 2                      Allison, Miss. Helen Loraine   2.00  female
# 3              Allison, Mr. Hudson Joshua Creighton  30.00    male
# 4   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00  female
# 5                               Anderson, Mr. Harry  48.00    male
# 6                 Andrews, Miss. Kornelia Theodosia  63.00  female
# 7                            Andrews, Mr. Thomas Jr  39.00    male
# 8     Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.00  female
# 9                           Artagaveytia, Mr. Ramon  71.00    male
# 10                           Astor, Col. John Jacob  47.00    male
#
#     survival_status
# 0                 1
# 1                 1
# 2                 0
# 3                 0
# 4                 0
# 5                 1
# ...

# %% [markdown]
# # membuat kolom tipedata datetime

# %%
dates = {
    'day': [11,12,13,14,15],
    'month': [2,1,3,7,5],
    'year': [2000,2003,2010,2012,2005]
}

df3 = pd.DataFrame(date).astype(int)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   day     5 non-null      int64
#  1   month   5 non-null      int64
#  2   year    5 non-null      int64
# dtypes: int64(3)
# memory usage: 248.0 bytes

# %%
df3['tanggal'] = pd.to_datetime(df3[['day','month','year']])
df3
# Out:
#    day  month  year    tanggal
# 0   11      2  2000 2000-02-11
# 1   12      1  2003 2003-01-12
# 2   13      3  2010 2010-03-13
# 3   14      7  2012 2012-07-14
# 4   15      5  2005 2005-05-15

# %% [markdown]
# # grouping data by kondisi

# %%
df['age_group'] = pd.cut(
    df['age'], 
    bins=[0, 18, 65, 99], 
    labels=['anak2','dewasa','manula']
)
df
# Out:
#       pclass  survival_status  \
# 0          1                1
# 1          1                1
# 2          1                0
# 3          1                0
# 4          1                0
# ...      ...              ...
# 1304       3                0
# 1305       3                0
# 1306       3                0
# 1307       3                0
# 1308       3                0
#
#                                             full_name     sex    age  sib_sp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.00       0
# 1                      Allison, Master. Hudson Trevor    male   0.92       1
# 2                        Allison, Miss. Helen Loraine  female   2.00       1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00       1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00       1
# ...                                               ...     ...    ...     ...
# ...

# %% [markdown]
# # menggabungkan 2 data frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  12  18  10  17   8
# 1  18  15   6  15   2
# 2   1  11  12  18   8
# 3   2  10   1  14  10
# 4  12  11  10   7  12

# %%
df1 = df.copy(deep=True)
df1 = df1.drop([0, 3])
df1
# Out:
#     A   B   C   D   E
# 1  18  15   6  15   2
# 2   1  11  12  18   8
# 4  12  11  10   7  12

# %%
df2 = df.copy(deep=True)
df2 = df2.drop([1, 4])
df2
# Out:
#     A   B   C   D   E
# 0  12  18  10  17   8
# 2   1  11  12  18   8
# 3   2  10   1  14  10

# %%
df_inner = pd.merge(df1, df2, how='inner') #--> inner menghasilkan data yg sama
df_inner
# Out:
#    A   B   C   D  E
# 0  1  11  12  18  8

# %%
df_outer = pd.merge(df1, df2, how='outer') 
df_outer
#--> outer menghasilkan data clean (jika ada duplicate akan dibuang)
# Out:
#     A   B   C   D   E
# 0  18  15   6  15   2
# 1   1  11  12  18   8
# 2  12  11  10   7  12
# 3  12  18  10  17   8
# 4   2  10   1  14  10

# %% [markdown]
# # memecah string kedalam kolom baru

# %%
datas= {
    'nama': ['Didi Kempot', 'Ariel Noah', 'Anji Drive'],
    'tempat_lahir': ['Solo, Jawa Tengah', 'Bandung, Jawa Barat', 'Jakarta Selatan, DKI Jakarta']
}
df2 = pd.DataFrame(datas)
df2
# Out:
#           nama                  tempat_lahir
# 0  Didi Kempot             Solo, Jawa Tengah
# 1   Ariel Noah           Bandung, Jawa Barat
# 2   Anji Drive  Jakarta Selatan, DKI Jakarta

# %%
df2[['nama_depan', 'nama_belakang']] = df2['nama'].str.split(' ', expand=True)
df2
# Out:
#           nama                  tempat_lahir nama_depan nama_belakang
# 0  Didi Kempot             Solo, Jawa Tengah       Didi        Kempot
# 1   Ariel Noah           Bandung, Jawa Barat      Ariel          Noah
# 2   Anji Drive  Jakarta Selatan, DKI Jakarta       Anji         Drive

# %%
df2[['kota', 'provinsi']] = df2['tempat_lahir'].str.split(',', expand=True)
df2
# Out:
#           nama                  tempat_lahir nama_depan nama_belakang  \
# 0  Didi Kempot             Solo, Jawa Tengah       Didi        Kempot
# 1   Ariel Noah           Bandung, Jawa Barat      Ariel          Noah
# 2   Anji Drive  Jakarta Selatan, DKI Jakarta       Anji         Drive
#
#               kota      provinsi
# 0             Solo   Jawa Tengah
# 1          Bandung    Jawa Barat
# 2  Jakarta Selatan   DKI Jakarta
